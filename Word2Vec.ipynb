# %% [markdown]
# ### Word 2 vec - Convert text to vector
# #### word 2 vec basically most popular becasue it uses neural network to learn word association from large corpus of text -> once trained such a model can able to detect synonum and suggest new vocabulary
# ##### word2vec get 300 feature representation vector Dimantion ###### it uses co-sin similarity to notice word importance

# %% [markdown]
# #### word ro vec has 2 types 1) Continuous bag of word 2) Skip Gram

# %% [markdown]
# ##### 1) CBow -> is fully connected neural netword
# ######    a) It has windows size -> featur representation(300 representation dimention -> google trained model)
# ######    b)it depenet of ANN and Loss function

# %% [markdown]
# ### Advantage
# ###### Space matrix -> you are actually get Dance matric
# ###### Semantic information captured -> because it handle the word importance
# ###### Vocabulary size is good
# ###### Fixed Input size Vector dimention 300
# ###### Resolved out of vacabulary => we have will get synonums and suggestion

# %%
pip install gensim
# Out:
# ...
#    ---------------------------------------- 0.0/24.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/24.0 MB 1.4 MB/s eta 0:00:18
#    ---------------------------------------- 0.1/24.0 MB 1.6 MB/s eta 0:00:16
#     --------------------------------------- 0.3/24.0 MB 2.6 MB/s eta 0:00:10
#     --------------------------------------- 0.5/24.0 MB 3.0 MB/s eta 0:00:08
#    - -------------------------------------- 0.7/24.0 MB 3.2 MB/s eta 0:00:08
#    -- ------------------------------------- 1.2/24.0 MB 4.9 MB/s eta 0:00:05
#    -- ------------------------------------- 1.8/24.0 MB 6.2 MB/s eta 0:00:04
#    ---- ----------------------------------- 2.7/24.0 MB 8.2 MB/s eta 0:00:03
#    ----- ---------------------------------- 3.5/24.0 MB 9.3 MB/s eta 0:00:03
#    ------- -------------------------------- 4.5/24.0 MB 10.9 MB/s eta 0:00:02
#    -------- ------------------------------- 5.2/24.0 MB 11.8 MB/s eta 0:00:02
# ...

# %%
import gensim

# %%
from gensim.models import word2vec,keyedvectors

# %%
import gensim.downloader as api

# %%
word2VecApi= api.load('word2vec-google-news-300')
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
word2VecApi["king"]
# Out:
# array([ 1.25976562e-01,  2.97851562e-02,  8.60595703e-03,  1.39648438e-01,
#        -2.56347656e-02, -3.61328125e-02,  1.11816406e-01, -1.98242188e-01,
#         5.12695312e-02,  3.63281250e-01, -2.42187500e-01, -3.02734375e-01,
#        -1.77734375e-01, -2.49023438e-02, -1.67968750e-01, -1.69921875e-01,
#         3.46679688e-02,  5.21850586e-03,  4.63867188e-02,  1.28906250e-01,
#         1.36718750e-01,  1.12792969e-01,  5.95703125e-02,  1.36718750e-01,
#         1.01074219e-01, -1.76757812e-01, -2.51953125e-01,  5.98144531e-02,
#         3.41796875e-01, -3.11279297e-02,  1.04492188e-01,  6.17675781e-02,
#         1.24511719e-01,  4.00390625e-01, -3.22265625e-01,  8.39843750e-02,
#         3.90625000e-02,  5.85937500e-03,  7.03125000e-02,  1.72851562e-01,
#         1.38671875e-01, -2.31445312e-01,  2.83203125e-01,  1.42578125e-01,
#         3.41796875e-01, -2.39257812e-02, -1.09863281e-01,  3.32031250e-02,
# ...

# %%
test = word2VecApi["man"]-word2VecApi["man"]+word2VecApi["women"]

# %%
word2VecApi.similar_by_word(test)
# Out:
# [('women', 1.0000001192092896),
#  ('men', 0.767493724822998),
#  ('Women', 0.7283449769020081),
#  ('womens', 0.6786180734634399),
#  ('girls', 0.6339040398597717),
#  ('females', 0.6240420341491699),
#  ('mothers', 0.6050933599472046),
#  ('ladies', 0.5865179300308228),
#  ('husbands', 0.5705342292785645),
#  ('transwomen', 0.5697940587997437)]
